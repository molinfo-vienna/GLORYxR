# %%
import subprocess
from pathlib import Path

from tqdm.auto import tqdm

# %%
OUTPUT_PATH = Path("../models")

# %%
model_paths = {
    "Phase 1 SyGMa rules": Path("../datasets/MetaQSAR_data/p1.sdf"),
    "CYP rules from GLORY (phase 1)": Path("../datasets/MetaQSAR_data/p1.sdf"),
    "Other phase 2 rules": Path("../datasets/MetaQSAR_data/p2.sdf"),
    "UGT rules (phase 2)": Path("../datasets/MetaQSAR_data/GLORYxR_specials/UGT.sdf"),
    "GST rules (phase 2)": Path("../datasets/MetaQSAR_data/GLORYxR_specials/GST.sdf"),
    "NAT rules (phase 2)": Path("../datasets/MetaQSAR_data/GLORYxR_specials/NAT.sdf"),
    "SULT rules (phase 2)": Path("../datasets/MetaQSAR_data/GLORYxR_specials/SULT.sdf"),
    "MT rules (phase 2)": Path("../datasets/MetaQSAR_data/GLORYxR_specials/MT.sdf"),
}

# %%
for name, path in tqdm(model_paths.items()):
    subprocess.check_output(
        [
            "fame3r",
            "train",
            "-i",
            path,
            "-o",
            OUTPUT_PATH,
            "--radius",
            "5",
        ]
    )

    (OUTPUT_PATH / "random_forest_classifier.joblib").rename(
        OUTPUT_PATH / f"{name}.joblib"
    )
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# ⠋ Training random forest on 39899 atoms (1692 molecules) 0:01:40
# ⠿ Training random forest on 39899 atoms (1692 molecules) 0:01:40
# ⠧ Training FAME score estimator on 39899 atoms (1692 molecules) 0:00:16
# ⠿ Training FAME score estimator on 39899 atoms (1692 molecules) 0:00:16
# ⠴ Training random forest on 39899 atoms (1692 molecules) 0:01:40
# ⠿ Training random forest on 39899 atoms (1692 molecules) 0:01:40
# ⠏ Training FAME score estimator on 39899 atoms (1692 molecules) 0:00:16
# ⠿ Training FAME score estimator on 39899 atoms (1692 molecules) 0:00:16
# ⠧ Training random forest on 22567 atoms (1059 molecules) 0:00:47
# ⠿ Training random forest on 22567 atoms (1059 molecules) 0:00:47
# ⠧ Training FAME score estimator on 22567 atoms (1059 molecules) 0:00:09
# ⠿ Training FAME score estimator on 22567 atoms (1059 molecules) 0:00:09
# ⠹ Training random forest on 16549 atoms (692 molecules) 0:00:31
# ⠿ Training random forest on 16549 atoms (692 molecules) 0:00:31
# ⠏ Training FAME score estimator on 16549 atoms (692 molecules) 0:00:07
# ⠿ Training FAME score estimator on 16549 atoms (692 molecules) 0:00:07
# ⠴ Training random forest on 6635 atoms (360 molecules) 0:00:13
# ⠿ Training random forest on 6635 atoms (360 molecules) 0:00:13
# ⠸ Training FAME score estimator on 6635 atoms (360 molecules) 0:00:02
# ⠿ Training FAME score estimator on 6635 atoms (360 molecules) 0:00:02
# ⠸ Training random forest on 1415 atoms (82 molecules) 0:00:01
# ⠿ Training random forest on 1415 atoms (82 molecules) 0:00:01
# ⠧ Training FAME score estimator on 1415 atoms (82 molecules) 0:00:00
# ⠿ Training FAME score estimator on 1415 atoms (82 molecules) 0:00:00
# ⠧ Training random forest on 2595 atoms (150 molecules) 0:00:03
# ⠿ Training random forest on 2595 atoms (150 molecules) 0:00:03
# ⠸ Training FAME score estimator on 2595 atoms (150 molecules) 0:00:01
# ⠿ Training FAME score estimator on 2595 atoms (150 molecules) 0:00:01
# ⠧ Training random forest on 1532 atoms (58 molecules) 0:00:02
# ⠿ Training random forest on 1532 atoms (58 molecules) 0:00:02
# ⠇ Training FAME score estimator on 1532 atoms (58 molecules) 0:00:00
# ⠿ Training FAME score estimator on 1532 atoms (58 molecules) 0:00:00
